# %%
import torch
from torchvision.models import resnet18, ResNet18_Weights
model = resnet18(weights=ResNet18_Weights.DEFAULT)
data = torch.rand(1, 3, 64, 64)
labels = torch.rand(1, 1000)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 146MB/s]

# %%
import matplotlib.pyplot as plt

plt.imshow(data.squeeze().permute(1,2,0))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(63.5), np.float64(63.5), np.float64(-0.5))

# %% [markdown]
# What Your Output Means:
#
# Because you used, data = torch.rand(1, 3, 64, 64)
# PyTorch generates random values between 0 and 1 for each pixel channel.

# %%
#print(labels)
print(labels[0][:10])
# Out:
# tensor([0.7206, 0.3379, 0.6871, 0.4635, 0.6501, 0.8613, 0.9892, 0.4971, 0.7384,
#         0.4882])

# %%
prediction = model(data) # forward pass

# %%
loss = (prediction - labels).sum()
loss.backward() # backward pass

# %%
optim = torch.optim.SGD(model.parameters(), lr=1e-2, momentum=0.9)

# %%
optim.step() #gradient descent
